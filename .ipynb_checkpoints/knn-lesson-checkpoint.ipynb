# %% [markdown]
# # Objectives
# YWBAT
# * make data for experimentation
# * apply a KNN model to data
# * find the best K for a KNN
# * evaluate a KNN with a confusion matrix
# * evaluate KNN models from a gridsearch

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd 
import numpy as np 

from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, train_test_split 
from sklearn.datasets import make_blobs 

import matplotlib.pyplot as plt
import seaborn as sns

# %%
X, y = make_blobs(n_samples=1000, n_features=2, centers=2)

# %%
df = pd.DataFrame(data=X, columns=['X1', 'X2'])
df['class'] = y 
df.head()
# Out:
#          X1        X2  class
# 0 -6.082265  7.505877      0
# 1 -6.695513  6.600138      0
# 2 -0.553513  6.466896      1
# 3 -1.607604  7.125778      1
# 4 -0.691945  5.377611      1

# %%
sns.scatterplot(x='X1', y='X2', hue='class', data=df)
plt.show()
